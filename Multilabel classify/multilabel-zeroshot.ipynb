# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/train.csv
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/test.csv
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31973.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30778.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19812.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22735.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38246.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16916.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39500.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7981.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34410.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39101.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22706.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20513.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12666.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13288.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20088.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36417.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37459.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6234.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36765.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38745.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28578.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1269.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38264.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22288.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24819.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3863.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34491.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6241.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25540.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20529.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10304.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27582.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/623.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2193.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14143.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33678.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11925.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21440.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3750.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11378.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2008.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10730.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17338.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22608.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16730.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33135.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5982.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33119.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34948.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30768.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7737.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26556.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32573.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2081.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26645.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14986.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23407.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35303.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10597.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37867.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34283.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34530.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19299.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6588.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35045.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10054.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32192.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12992.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7966.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23149.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3919.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38597.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6197.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30325.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10924.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15653.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21494.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24752.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39765.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38954.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33733.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20777.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21838.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39055.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6399.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32690.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25184.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39527.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30273.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27345.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9960.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26076.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37468.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27577.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33298.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37154.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39213.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27053.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3757.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9131.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19798.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13856.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26072.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37488.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29995.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34292.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9620.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9062.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4489.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3138.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10213.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30071.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3417.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33338.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37346.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6074.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29970.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37511.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36043.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38595.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5705.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35990.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37232.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26623.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19674.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29112.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35390.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28165.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26142.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28204.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8953.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/764.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5307.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39221.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7894.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5039.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10305.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4407.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1700.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32279.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17257.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34955.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1786.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26946.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17720.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2907.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8930.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11138.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16257.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25501.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6324.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15979.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1075.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4969.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18516.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36576.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31138.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8983.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28375.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5584.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27973.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10627.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36162.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35535.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23274.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35105.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30731.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9697.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3501.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10037.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2863.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/771.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8352.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/208.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23775.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12167.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17643.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28726.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35344.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22046.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29411.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11868.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26853.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39125.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14167.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20938.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4640.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21590.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7222.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26538.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17672.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13839.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26452.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15082.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5333.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4125.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14312.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24667.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6560.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25858.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23436.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28760.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2628.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26518.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34401.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34690.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21575.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23710.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22604.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16202.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10162.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30371.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28686.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15572.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19901.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27650.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8104.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25261.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28040.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3363.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13333.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33453.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4009.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37478.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9645.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37829.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30461.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15823.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14395.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25171.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9579.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20833.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/820.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6943.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3228.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37962.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12132.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20684.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8075.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18129.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13899.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32304.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36460.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26475.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26107.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6272.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1789.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38346.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6365.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25869.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20554.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6459.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5052.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39964.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23753.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7690.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36046.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21966.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36702.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15783.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36091.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6653.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28106.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23566.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16385.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/473.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8864.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12768.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23474.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3446.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13087.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11034.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31620.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27755.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1792.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4772.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30127.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38333.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16016.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32218.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26591.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21145.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7427.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24692.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38070.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39540.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37629.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8623.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7006.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23273.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12551.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28271.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36220.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2936.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2029.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13118.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6925.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26803.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4313.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23031.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6295.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20010.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38743.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38875.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5018.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38445.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27092.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24487.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13205.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8914.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15764.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11251.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1411.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23098.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7918.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4275.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7245.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24392.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24350.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29603.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20100.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36119.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35919.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29977.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32057.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33844.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22711.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16401.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3532.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20789.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7802.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13911.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1031.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1833.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11617.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38780.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14397.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20076.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35208.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23258.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39716.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14897.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12389.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34814.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23220.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2675.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5627.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33852.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39152.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35737.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19651.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6800.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32743.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30611.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7962.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30486.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11921.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25779.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23094.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27613.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10255.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10825.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12414.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18945.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28806.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14376.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25469.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24969.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21232.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20321.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13049.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36014.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28516.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11236.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12267.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2172.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18227.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35702.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4765.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22270.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25990.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21588.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21947.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6209.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6899.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18672.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34210.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29491.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8442.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11522.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5068.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11529.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11956.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6229.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28319.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1749.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1501.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9606.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14129.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11684.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39382.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8543.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2021.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29648.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15360.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36744.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29764.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11855.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14328.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25310.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17190.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5886.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33021.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18950.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32340.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24778.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30415.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37280.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21154.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13314.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7384.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30059.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16652.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3899.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23596.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29223.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27382.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28091.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27376.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24917.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1995.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30147.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30579.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5477.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20978.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38721.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24068.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1385.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3651.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8342.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13200.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27641.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30145.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35485.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18048.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15103.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38800.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7544.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4398.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30982.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19407.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4581.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39564.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16504.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12334.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20429.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3537.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21946.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28604.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16638.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5575.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20825.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2278.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21701.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11901.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26474.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28621.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25558.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12675.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24267.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17474.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33882.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27656.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20906.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29360.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15785.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24785.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27277.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14619.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6831.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20308.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18399.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18700.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29345.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27186.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8929.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1971.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13594.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12882.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27768.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30729.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6248.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38357.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18335.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7061.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33862.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28797.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26320.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30247.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30073.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39156.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26291.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16993.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21093.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12303.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3807.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1383.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15463.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23053.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12532.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36612.jpg
# ...
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36248.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4490.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29598.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18277.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37374.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3267.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35539.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11519.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24159.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32116.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26942.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/12784.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29976.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30219.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8481.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39584.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8217.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3120.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17867.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11783.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7878.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25605.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31664.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2867.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22473.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7370.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36594.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5272.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7156.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22328.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1801.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3000.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16441.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15562.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8193.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6785.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36852.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28960.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37321.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34191.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16380.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11091.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27234.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7105.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36213.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27668.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15694.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6710.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4421.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21981.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32092.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14936.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11884.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8806.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33097.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/14667.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5894.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25882.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1979.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13307.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10802.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19736.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/34204.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21691.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3059.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7842.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38766.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31606.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35166.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3410.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2085.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13900.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/27173.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18740.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16373.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32666.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39588.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16494.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10371.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22668.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9843.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/26657.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23154.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10129.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36157.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10226.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/35082.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/36428.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4968.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7318.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23544.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18528.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21317.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10974.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17442.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18861.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33348.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5922.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/24492.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25690.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/147.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29822.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9201.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5005.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8281.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31562.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/15816.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23416.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13114.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33643.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/38425.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22159.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7473.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29095.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/25804.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/13877.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29012.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5088.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23168.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5254.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28623.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11205.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23863.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7138.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/17953.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/9508.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/19101.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22744.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/921.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/4463.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/7674.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20038.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31854.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37710.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3950.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8684.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/20287.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/5303.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29236.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/37230.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/29510.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/728.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33570.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23874.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33395.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21432.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32077.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/1656.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32326.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8658.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/33775.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28546.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/6119.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28874.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/28964.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/32970.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/8152.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/39690.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/18973.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/3361.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31858.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/22292.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/30047.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/16986.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/21885.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/2599.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/10035.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/31745.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/11590.jpg
# /kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/23579.jpg

# %%
# ======================================================================================
#                              SETUP AND IMPORTS
# ======================================================================================
import os
import sys
import pandas as pd
import numpy as np
from PIL import Image
import cv2
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score
from tqdm.notebook import tqdm if 'ipykernel' in sys.modules else tqdm # Progress bar for notebooks or scripts
import timm
from sentence_transformers import SentenceTransformer
import gc
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# ======================================================================================
#                          CONFIGURATION & HYPERPARAMETERS
# ======================================================================================
class CFG:
    """
    Configuration class for all hyperparameters and settings.
    """
    # General
    SEED = 42
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Data paths
    DATA_DIR = "/kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/data/"
    TRAIN_CSV = "/kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/train.csv"
    TEST_CSV = "/kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/test.csv"
    SUBMISSION_FILE = "/kaggle/input/multi-label-classification-competition-2025/COMP5329S1A2Dataset/submission.csv"

    # Model parameters
    IMAGE_MODEL_NAME = 'vit_base_patch16_224' # A powerful Vision Transformer
    TEXT_MODEL_NAME = 'all-MiniLM-L6-v2'      # A fast and effective sentence transformer
    IMAGE_SIZE = 224
    TEXT_EMBEDDING_DIM = 384 # Dimension of 'all-MiniLM-L6-v2' embeddings
    
    # Training parameters
    EPOCHS = 8
    BATCH_SIZE = 32
    LEARNING_RATE = 1e-4
    WEIGHT_DECAY = 1e-6
    N_FOLDS = 1 # For simplicity, we'll run a single train/validation split. Change to 5 for 5-fold CV.
    
    # Prediction
    PREDICTION_THRESHOLD = 0.4 # Threshold to convert probabilities to binary labels

# Helper function to seed everything for reproducibility
def set_seed(seed=CFG.SEED):
    """Sets the seed for reproducibility."""
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

# ======================================================================================
#                          GENERATE DUMMY DATA (for testing)
# ======================================================================================
def create_dummy_data():
    """
    Creates dummy data files if they don't exist. This allows the script
    to be run end-to-end without the actual dataset.
    """
    # Create data directory
    os.makedirs(CFG.DATA_DIR, exist_ok=True)
    
    # Create dummy train.csv
    if not os.path.exists(CFG.TRAIN_CSV):
        print("Creating dummy train.csv...")
        train_data = []
        all_labels = [i for i in range(1, 20) if i != 12]
        for i in range(100): # 100 dummy samples
            img_id = f"train_{i:04d}.jpg"
            # Generate 1 to 3 random labels
            num_labels = np.random.randint(1, 4)
            labels = np.random.choice(all_labels, num_labels, replace=False)
            labels_str = " ".join(map(str, labels))
            caption = f"A sample caption for image {i}"
            train_data.append([img_id, labels_str, caption])
            # Create a dummy image file
            dummy_image = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
            cv2.imwrite(os.path.join(CFG.DATA_DIR, img_id), dummy_image)
        pd.DataFrame(train_data, columns=['ImageID', 'Labels', 'Caption']).to_csv(CFG.TRAIN_CSV, index=False)
        
    # Create dummy test.csv
    if not os.path.exists(CFG.TEST_CSV):
        print("Creating dummy test.csv...")
        test_data = []
        for i in range(50): # 50 dummy test samples
            img_id = f"test_{i:04d}.jpg"
            caption = f"A test caption for image {i}"
            test_data.append([img_id, caption])
            # Create a dummy image file
            dummy_image = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
            cv2.imwrite(os.path.join(CFG.DATA_DIR, img_id), dummy_image)
        pd.DataFrame(test_data, columns=['ImageID', 'Caption']).to_csv(CFG.TEST_CSV, index=False)

# ======================================================================================
#                        DATA PREPARATION AND PREPROCESSING
# ======================================================================================
def prepare_data():
    """
    Loads and preprocesses the training and testing data.
    - Encodes labels into a multi-hot format.
    - Generates text embeddings using a sentence transformer.
    """
    print("Preparing data...")
    train_df = pd.read_csv(CFG.TRAIN_CSV)
    test_df = pd.read_csv(CFG.TEST_CSV)
    
    # --- Process file paths ---
    train_df['image_path'] = train_df['ImageID'].apply(lambda x: os.path.join(CFG.DATA_DIR, x))
    test_df['image_path'] = test_df['ImageID'].apply(lambda x: os.path.join(CFG.DATA_DIR, x))
    
    # --- Handle optional captions ---
    # Fill missing captions with an empty string
    train_df['Caption'] = train_df['Caption'].fillna('')
    test_df['Caption'] = test_df['Caption'].fillna('')
    
    # --- Process Labels ---
    # Convert space-separated string of labels to a list of integers
    train_df['Labels'] = train_df['Labels'].apply(lambda x: [int(i) for i in x.split()])
    
    # Use MultiLabelBinarizer to one-hot encode the labels
    mlb = MultiLabelBinarizer()
    train_labels = mlb.fit_transform(train_df['Labels'])
    
    # Store encoded labels back into the DataFrame
    train_df['encoded_labels'] = list(train_labels)
    
    print(f"Label classes found: {mlb.classes_}")
    
    # --- Generate Text Embeddings ---
    print("Generating text embeddings... (This might take a while)")
    text_model = SentenceTransformer(CFG.TEXT_MODEL_NAME, device=CFG.DEVICE)
    
    # It's more efficient to encode all captions at once
    train_captions = train_df['Caption'].tolist()
    test_captions = test_df['Caption'].tolist()
    
    # Generate embeddings
    train_text_embeddings = text_model.encode(train_captions, show_progress_bar=True, batch_size=CFG.BATCH_SIZE*2)
    test_text_embeddings = text_model.encode(test_captions, show_progress_bar=True, batch_size=CFG.BATCH_SIZE*2)
    
    train_df['text_embeddings'] = list(train_text_embeddings)
    test_df['text_embeddings'] = list(test_text_embeddings)
    
    # Clean up GPU memory
    del text_model
    gc.collect()
    torch.cuda.empty_cache()
    
    return train_df, test_df, mlb

# ======================================================================================
#                              PYTORCH DATASET
# ======================================================================================
class MultimodalDataset(Dataset):
    """
    Custom PyTorch Dataset for multimodal data (image + text).
    """
    def __init__(self, df, transforms=None, is_test=False):
        self.df = df
        self.transforms = transforms
        self.is_test = is_test

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        
        # --- Image ---
        image = Image.open(row['image_path']).convert('RGB')
        if self.transforms:
            image = np.array(image) # Albumentations requires numpy array
            image = self.transforms(image=image)['image']
        
        # --- Text ---
        text_embedding = torch.tensor(row['text_embeddings'], dtype=torch.float)
        
        if self.is_test:
            return image, text_embedding
        else:
            # --- Labels ---
            labels = torch.tensor(row['encoded_labels'], dtype=torch.float)
            return image, text_embedding, labels

# Image transformations using Albumentations
def get_transforms():
    """Returns a dictionary of train and validation transforms."""
    # Mean and std for ImageNet pre-trained models
    mean, std = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
    
    train_transforms = transforms.Compose([
        transforms.Resize((CFG.IMAGE_SIZE, CFG.IMAGE_SIZE)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])
    
    # For validation and test, we only resize, convert to tensor and normalize
    valid_transforms = transforms.Compose([
        transforms.Resize((CFG.IMAGE_SIZE, CFG.IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])

    # Let's switch to torchvision transforms for simplicity in this script
    # To use Albumentations, you would keep the numpy conversion in __getitem__
    # For now, we will use PIL-based transforms from torchvision
    return {'train': train_transforms, 'valid': valid_transforms}

# ======================================================================================
#                                MODEL ARCHITECTURE
# ======================================================================================
class MultimodalModel(nn.Module):
    """
    A multimodal model that fuses features from an image model and a text model.
    """
    def __init__(self, num_classes, image_model_name=CFG.IMAGE_MODEL_NAME, text_embedding_dim=CFG.TEXT_EMBEDDING_DIM):
        super().__init__()
        
        # --- Image Branch ---
        self.image_model = timm.create_model(image_model_name, pretrained=True, num_classes=0) # num_classes=0 returns features
        num_image_features = self.image_model.num_features
        
        # --- Text Branch (a simple MLP) ---
        self.text_model = nn.Sequential(
            nn.Linear(text_embedding_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        
        # --- Classifier Head ---
        # Concatenated features from both branches
        fused_features_dim = num_image_features + 512
        self.classifier = nn.Sequential(
            nn.Linear(fused_features_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, image, text_embedding):
        image_features = self.image_model(image)
        text_features = self.text_model(text_embedding)
        
        # Concatenate features
        fused_features = torch.cat([image_features, text_features], dim=1)
        
        # Get logits
        output = self.classifier(fused_features)
        return output

# ======================================================================================
#                             TRAINING & VALIDATION LOOPS
# ======================================================================================

def train_one_epoch(model, dataloader, optimizer, criterion, device):
    """Trains the model for one epoch."""
    model.train()
    total_loss = 0
    progress_bar = tqdm(dataloader, desc="Training", leave=False)
    
    for images, text_embeds, labels in progress_bar:
        images, text_embeds, labels = images.to(device), text_embeds.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images, text_embeds)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        progress_bar.set_postfix(loss=loss.item())
        
    return total_loss / len(dataloader)

def validate_one_epoch(model, dataloader, criterion, device, threshold):
    """Validates the model for one epoch."""
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        progress_bar = tqdm(dataloader, desc="Validation", leave=False)
        for images, text_embeds, labels in progress_bar:
            images, text_embeds, labels = images.to(device), text_embeds.to(device), labels.to(device)
            
            outputs = model(images, text_embeds)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            
            # Get predictions
            probs = torch.sigmoid(outputs)
            preds = (probs > threshold).cpu().numpy()
            
            all_preds.append(preds)
            all_labels.append(labels.cpu().numpy())
            
    # Concatenate all batches
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)
    
    # Calculate Mean F1-Score (macro average)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    
    return total_loss / len(dataloader), f1

# ======================================================================================
#                                    MAIN EXECUTION
# ======================================================================================
def main():
    """Main function to run the entire pipeline."""
    set_seed(CFG.SEED)
    create_dummy_data() # Create dummy data if real data is not available
    
    train_df, test_df, mlb = prepare_data()
    num_classes = len(mlb.classes_)
    
    # --- Data Splitting ---
    # For a robust solution, consider StratifiedKFold from skmultilearn
    # Here, we use a simple train_test_split for demonstration
    train_data, val_data = train_test_split(train_df, test_size=0.2, random_state=CFG.SEED)
    
    transforms_dict = get_transforms()
    
    # --- Create Datasets and Dataloaders ---
    train_dataset = MultimodalDataset(train_data, transforms=transforms_dict['train'])
    val_dataset = MultimodalDataset(val_data, transforms=transforms_dict['valid'])
    
    train_loader = DataLoader(train_dataset, batch_size=CFG.BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=CFG.BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
    
    # --- Model, Loss, Optimizer ---
    print(f"Initializing model on device: {CFG.DEVICE}")
    model = MultimodalModel(num_classes=num_classes).to(CFG.DEVICE)
    
    # BCEWithLogitsLoss is ideal for multi-label classification
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=CFG.LEARNING_RATE, weight_decay=CFG.WEIGHT_DECAY)
    
    # --- Training Loop ---
    best_f1 = -1
    best_model_path = "best_model.pth"
    
    for epoch in range(CFG.EPOCHS):
        print(f"\n===== Epoch {epoch+1}/{CFG.EPOCHS} =====")
        
        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, CFG.DEVICE)
        val_loss, val_f1 = validate_one_epoch(model, val_loader, criterion, CFG.DEVICE, CFG.PREDICTION_THRESHOLD)
        
        print(f"Epoch {epoch+1}: Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val F1 (macro): {val_f1:.4f}")
        
        # Save the best model based on validation F1 score
        if val_f1 > best_f1:
            best_f1 = val_f1
            print(f"🎉 New best F1 score: {best_f1:.4f}. Saving model to {best_model_path}")
            torch.save(model.state_dict(), best_model_path)
    
    print(f"\nTraining complete. Best validation F1 score: {best_f1:.4f}")
    
    # --- Inference on Test Set ---
    print("\nStarting inference on the test set...")
    
    # Load the best model for inference
    model.load_state_dict(torch.load(best_model_path))
    model.eval()
    
    test_dataset = MultimodalDataset(test_df, transforms=transforms_dict['valid'], is_test=True)
    test_loader = DataLoader(test_dataset, batch_size=CFG.BATCH_SIZE, shuffle=False, num_workers=2)
    
    all_test_preds = []
    with torch.no_grad():
        for images, text_embeds in tqdm(test_loader, desc="Predicting"):
            images, text_embeds = images.to(CFG.DEVICE), text_embeds.to(CFG.DEVICE)
            
            outputs = model(images, text_embeds)
            probs = torch.sigmoid(outputs)
            preds = (probs > CFG.PREDICTION_THRESHOLD).cpu().numpy()
            all_test_preds.append(preds)
            
    all_test_preds = np.concatenate(all_test_preds, axis=0)
    
    # --- Create Submission File ---
    # Inverse transform the one-hot predictions back to original label numbers
    predicted_labels = mlb.inverse_transform(all_test_preds)
    
    # Format for submission: space-separated string
    predicted_labels_str = [" ".join(map(str, labels)) if labels else "" for labels in predicted_labels]
    
    submission_df = pd.DataFrame({
        'ImageID': test_df['ImageID'],
        'Labels': predicted_labels_str
    })
    
    submission_df.to_csv(CFG.SUBMISSION_FILE, index=False)
    print(f"\nSubmission file created at '{CFG.SUBMISSION_FILE}'")
    print("Sample of submission file:")
    print(submission_df.head())

if __name__ == '__main__':
    main()
# Out:
#   File "/tmp/ipykernel_35/1780463329.py", line 17
#     from tqdm.notebook import tqdm if 'ipykernel' in sys.modules else tqdm # Progress bar for notebooks or scripts
#                                    ^
# SyntaxError: invalid syntax
