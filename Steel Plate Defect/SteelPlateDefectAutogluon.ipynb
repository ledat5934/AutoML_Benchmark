# %%
# !pip install -U autogluon > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textblob 0.19.0 requires nltk>=3.9, but you have nltk 3.8.1 which is incompatible.

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.common.utils.utils import setup_outputdir
from autogluon.core.utils.loaders import load_pkl
from autogluon.core.utils.savers import save_pkl
import os.path

class MultilabelPredictor:
    """ Tabular Predictor for predicting multiple columns in table.
        Creates multiple TabularPredictor objects which you can also use individually.
        You can access the TabularPredictor for a particular label via: `multilabel_predictor.get_predictor(label_i)`

        Parameters
        ----------
        labels : List[str]
            The ith element of this list is the column (i.e. `label`) predicted by the ith TabularPredictor stored in this object.
        path : str, default = None
            Path to directory where models and intermediate outputs should be saved.
            If unspecified, a time-stamped folder called "AutogluonModels/ag-[TIMESTAMP]" will be created in the working directory to store all models.
            Note: To call `fit()` twice and save all results of each fit, you must specify different `path` locations or don't specify `path` at all.
            Otherwise files from first `fit()` will be overwritten by second `fit()`.
            Caution: when predicting many labels, this directory may grow large as it needs to store many TabularPredictors.
        problem_types : List[str], default = None
            The ith element is the `problem_type` for the ith TabularPredictor stored in this object.
        eval_metrics : List[str], default = None
            The ith element is the `eval_metric` for the ith TabularPredictor stored in this object.
        consider_labels_correlation : bool, default = True
            Whether the predictions of multiple labels should account for label correlations or predict each label independently of the others.
            If True, the ordering of `labels` may affect resulting accuracy as each label is predicted conditional on the previous labels appearing earlier in this list (i.e. in an auto-regressive fashion).
            Set to False if during inference you may want to individually use just the ith TabularPredictor without predicting all the other labels.
        kwargs :
            Arguments passed into the initialization of each TabularPredictor.

    """

    multi_predictor_file = 'multilabel_predictor.pkl'

    def __init__(self, labels, path=None, problem_types=None, eval_metrics=None, consider_labels_correlation=True, **kwargs):
        if len(labels) < 2:
            raise ValueError("MultilabelPredictor is only intended for predicting MULTIPLE labels (columns), use TabularPredictor for predicting one label (column).")
        if (problem_types is not None) and (len(problem_types) != len(labels)):
            raise ValueError("If provided, `problem_types` must have same length as `labels`")
        if (eval_metrics is not None) and (len(eval_metrics) != len(labels)):
            raise ValueError("If provided, `eval_metrics` must have same length as `labels`")
        self.path = setup_outputdir(path, warn_if_exist=False)
        self.labels = labels
        self.consider_labels_correlation = consider_labels_correlation
        self.predictors = {}  # key = label, value = TabularPredictor or str path to the TabularPredictor for this label
        if eval_metrics is None:
            self.eval_metrics = {}
        else:
            self.eval_metrics = {labels[i] : eval_metrics[i] for i in range(len(labels))}
        problem_type = None
        eval_metric = None
        for i in range(len(labels)):
            label = labels[i]
            path_i = os.path.join(self.path, "Predictor_" + str(label))
            if problem_types is not None:
                problem_type = problem_types[i]
            if eval_metrics is not None:
                eval_metric = eval_metrics[i]
            self.predictors[label] = TabularPredictor(label=label, problem_type=problem_type, eval_metric=eval_metric, path=path_i, **kwargs)

    def fit(self, train_data, tuning_data=None, **kwargs):
        """ Fits a separate TabularPredictor to predict each of the labels.

            Parameters
            ----------
            train_data, tuning_data : str or pd.DataFrame
                See documentation for `TabularPredictor.fit()`.
            kwargs :
                Arguments passed into the `fit()` call for each TabularPredictor.
        """
        if isinstance(train_data, str):
            train_data = TabularDataset(train_data)
        if tuning_data is not None and isinstance(tuning_data, str):
            tuning_data = TabularDataset(tuning_data)
        train_data_og = train_data.copy()
        if tuning_data is not None:
            tuning_data_og = tuning_data.copy()
        else:
            tuning_data_og = None
        save_metrics = len(self.eval_metrics) == 0
        for i in range(len(self.labels)):
            label = self.labels[i]
            predictor = self.get_predictor(label)
            if not self.consider_labels_correlation:
                labels_to_drop = [l for l in self.labels if l != label]
            else:
                labels_to_drop = [self.labels[j] for j in range(i+1, len(self.labels))]
            train_data = train_data_og.drop(labels_to_drop, axis=1)
            if tuning_data is not None:
                tuning_data = tuning_data_og.drop(labels_to_drop, axis=1)
            print(f"Fitting TabularPredictor for label: {label} ...")
            predictor.fit(train_data=train_data, tuning_data=tuning_data, **kwargs)
            self.predictors[label] = predictor.path
            if save_metrics:
                self.eval_metrics[label] = predictor.eval_metric
        self.save()

    def predict(self, data, **kwargs):
        """ Returns DataFrame with label columns containing predictions for each label.

            Parameters
            ----------
            data : str or autogluon.tabular.TabularDataset or pd.DataFrame
                Data to make predictions for. If label columns are present in this data, they will be ignored. See documentation for `TabularPredictor.predict()`.
            kwargs :
                Arguments passed into the predict() call for each TabularPredictor.
        """
        return self._predict(data, as_proba=False, **kwargs)

    def predict_proba(self, data, **kwargs):
        """ Returns dict where each key is a label and the corresponding value is the `predict_proba()` output for just that label.

            Parameters
            ----------
            data : str or autogluon.tabular.TabularDataset or pd.DataFrame
                Data to make predictions for. See documentation for `TabularPredictor.predict()` and `TabularPredictor.predict_proba()`.
            kwargs :
                Arguments passed into the `predict_proba()` call for each TabularPredictor (also passed into a `predict()` call).
        """
        return self._predict(data, as_proba=True, **kwargs)

    def evaluate(self, data, **kwargs):
        """ Returns dict where each key is a label and the corresponding value is the `evaluate()` output for just that label.

            Parameters
            ----------
            data : str or autogluon.tabular.TabularDataset or pd.DataFrame
                Data to evalate predictions of all labels for, must contain all labels as columns. See documentation for `TabularPredictor.evaluate()`.
            kwargs :
                Arguments passed into the `evaluate()` call for each TabularPredictor (also passed into the `predict()` call).
        """
        data = self._get_data(data)
        eval_dict = {}
        for label in self.labels:
            print(f"Evaluating TabularPredictor for label: {label} ...")
            predictor = self.get_predictor(label)
            eval_dict[label] = predictor.evaluate(data, **kwargs)
            if self.consider_labels_correlation:
                data[label] = predictor.predict(data, **kwargs)
        return eval_dict

    def save(self):
        """ Save MultilabelPredictor to disk. """
        for label in self.labels:
            if not isinstance(self.predictors[label], str):
                self.predictors[label] = self.predictors[label].path
        save_pkl.save(path=os.path.join(self.path, self.multi_predictor_file), object=self)
        print(f"MultilabelPredictor saved to disk. Load with: MultilabelPredictor.load('{self.path}')")

    @classmethod
    def load(cls, path):
        """ Load MultilabelPredictor from disk `path` previously specified when creating this MultilabelPredictor. """
        path = os.path.expanduser(path)
        return load_pkl.load(path=os.path.join(path, cls.multi_predictor_file))

    def get_predictor(self, label):
        """ Returns TabularPredictor which is used to predict this label. """
        predictor = self.predictors[label]
        if isinstance(predictor, str):
            return TabularPredictor.load(path=predictor)
        return predictor

    def _get_data(self, data):
        if isinstance(data, str):
            return TabularDataset(data)
        return data.copy()

    def _predict(self, data, as_proba=False, **kwargs):
        data = self._get_data(data)
        if as_proba:
            predproba_dict = {}
        for label in self.labels:
            print(f"Predicting with TabularPredictor for label: {label} ...")
            predictor = self.get_predictor(label)
            if as_proba:
                predproba_dict[label] = predictor.predict_proba(data, as_multiclass=True, **kwargs)
            data[label] = predictor.predict(data, **kwargs)
        if not as_proba:
            return data[self.labels]
        else:
            return predproba_dict

# %%
train_data = TabularDataset('train.csv')
train_data = train_data.drop('id', axis=1)
train_data.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0        584        590     909972     909977            16            8
# 1        808        816     728350     728372           433           20
# 2         39        192    2212076    2212144         11388          705
# 3        781        789    3353146    3353173           210           16
# 4       1540       1560     618457     618502           521           72
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0            5               2274                    113
# 1           54              44478                     70
# 2          420            1311391                     29
# 3           29               3202                    114
# 4           67              48231                     82
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    140  ...            -0.5000           -0.0104
# 1                    111  ...             0.7419           -0.2997
# 2                    141  ...            -0.0105           -0.0944
# 3                    134  ...             0.6667           -0.0402
# 4                    111  ...             0.9158           -0.2455
#
#    SigmoidOfAreas  Pastry  Z_Scratch  K_Scatch  Stains  Dirtiness  Bumps  \
# 0          0.1417       0          0         0       1          0      0
# 1          0.9491       0          0         0       0          0      0
# 2          1.0000       0          0         1       0          0      0
# 3          0.4025       0          0         1       0          0      0
# 4          0.9998       0          0         0       0          0      0
#
#    Other_Faults
# 0             0
# 1             1
# 2             0
# 3             0
# 4             1
#
# [5 rows x 34 columns]

# %%
labels = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']
problem_types = ['binary','binary','binary', 'binary', 'binary', 'binary', 'binary']
eval_metrics = ['roc_auc', 'roc_auc', 'roc_auc', 'roc_auc', 'roc_auc', 'roc_auc', 'roc_auc']

# %%
multi_predictor = MultilabelPredictor(labels=labels, problem_types=problem_types, eval_metrics=eval_metrics, consider_labels_correlation = True)
multi_predictor.fit(train_data, time_limit=600)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
# CPU Count:          2
# Memory Avail:       11.12 GB / 12.67 GB (87.7%)
# Disk Space Avail:   69.98 GB / 112.64 GB (62.1%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "/content/AutogluonModels/ag-20250627_135331/Predictor_Pastry"
# Train Data Rows:    19219
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11389.81 MB
# 	Train Data (Original)  Memory Usage: 3.96 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.70 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 17297, Val Rows: 1922
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ... Training model for up to 599.88s of the 599.88s of remaining time.
# Fitting TabularPredictor for label: Pastry ...
# 	0.5092	 = Validation score   (roc_auc)
# 	0.04s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 599.50s of the 599.50s of remaining time.
# 	0.5107	 = Validation score   (roc_auc)
# 	0.05s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 599.17s of the 599.17s of remaining time.
# 	0.879	 = Validation score   (roc_auc)
# 	5.34s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 593.79s of the 593.79s of remaining time.
# 	0.8783	 = Validation score   (roc_auc)
# 	1.27s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 592.50s of the 592.50s of remaining time.
# 	0.8544	 = Validation score   (roc_auc)
# 	10.69s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 581.63s of the 581.63s of remaining time.
# 	0.867	 = Validation score   (roc_auc)
# 	10.5s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 570.88s of the 570.88s of remaining time.
# 	0.8746	 = Validation score   (roc_auc)
# 	6.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 564.61s of the 564.61s of remaining time.
# 	0.8613	 = Validation score   (roc_auc)
# 	2.65s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 561.72s of the 561.71s of remaining time.
# 	0.8668	 = Validation score   (roc_auc)
# 	3.7s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 557.56s of the 557.56s of remaining time.
# 	0.8719	 = Validation score   (roc_auc)
# 	20.81s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 536.68s of the 536.68s of remaining time.
# 	0.8833	 = Validation score   (roc_auc)
# 	1.84s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 534.79s of the 534.79s of remaining time.
# 	0.8701	 = Validation score   (roc_auc)
# 	21.29s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 513.47s of the 513.47s of remaining time.
# 	0.8717	 = Validation score   (roc_auc)
# 	3.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 510.37s of remaining time.
# 	Ensemble Weights: {'XGBoost': 0.56, 'NeuralNetFastAI': 0.32, 'NeuralNetTorch': 0.08, 'LightGBM': 0.04}
# 	0.8876	 = Validation score   (roc_auc)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 89.81s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 19547.3 rows/s (1922 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20250627_135331/Predictor_Pastry")
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
# CPU Count:          2
# Memory Avail:       10.65 GB / 12.67 GB (84.0%)
# Disk Space Avail:   69.69 GB / 112.64 GB (61.9%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "/content/AutogluonModels/ag-20250627_135331/Predictor_Z_Scratch"
# Train Data Rows:    19219
# Train Data Columns: 28
# Label Column:       Z_Scratch
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10908.72 MB
# 	Train Data (Original)  Memory Usage: 4.11 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 15 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  3 | ['TypeOfSteel_A300', 'TypeOfSteel_A400', 'Pastry']
# 	0.1s = Fit runtime
# 	28 features in original data used to generate 28 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.72 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 17297, Val Rows: 1922
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ... Training model for up to 599.87s of the 599.87s of remaining time.
# Fitting TabularPredictor for label: Z_Scratch ...
# 	0.5539	 = Validation score   (roc_auc)
# 	0.04s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 599.56s of the 599.56s of remaining time.
# 	0.557	 = Validation score   (roc_auc)
# 	0.04s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 599.26s of the 599.26s of remaining time.
# 	0.96	 = Validation score   (roc_auc)
# 	2.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 597.18s of the 597.18s of remaining time.
# 	0.9621	 = Validation score   (roc_auc)
# 	1.43s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 595.73s of the 595.73s of remaining time.
# 	0.9466	 = Validation score   (roc_auc)
# 	7.96s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 587.60s of the 587.59s of remaining time.
# 	0.9557	 = Validation score   (roc_auc)
# 	9.45s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 578.01s of the 578.00s of remaining time.
# 	0.9622	 = Validation score   (roc_auc)
# 	5.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 572.99s of the 572.99s of remaining time.
# 	0.9467	 = Validation score   (roc_auc)
# 	2.46s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 570.32s of the 570.32s of remaining time.
# 	0.9476	 = Validation score   (roc_auc)
# 	2.43s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 567.66s of the 567.66s of remaining time.
# 	0.9545	 = Validation score   (roc_auc)
# 	15.81s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 551.80s of the 551.80s of remaining time.
# 	0.9619	 = Validation score   (roc_auc)
# 	1.7s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 550.06s of the 550.06s of remaining time.
# 	0.9504	 = Validation score   (roc_auc)
# 	25.07s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 524.95s of the 524.95s of remaining time.
# 	0.9615	 = Validation score   (roc_auc)
# 	3.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 521.03s of remaining time.
# 	Ensemble Weights: {'XGBoost': 0.333, 'CatBoost': 0.278, 'LightGBM': 0.111, 'NeuralNetFastAI': 0.111, 'KNeighborsUnif': 0.056, 'RandomForestGini': 0.056, 'NeuralNetTorch': 0.056}
# 	0.9674	 = Validation score   (roc_auc)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 79.15s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 4333.8 rows/s (1922 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20250627_135331/Predictor_Z_Scratch")
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
# CPU Count:          2
# Memory Avail:       10.55 GB / 12.67 GB (83.2%)
# Disk Space Avail:   69.51 GB / 112.64 GB (61.7%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "/content/AutogluonModels/ag-20250627_135331/Predictor_K_Scatch"
# Train Data Rows:    19219
# Train Data Columns: 29
# Label Column:       K_Scatch
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10805.17 MB
# 	Train Data (Original)  Memory Usage: 4.25 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 16 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  4 | ['TypeOfSteel_A300', 'TypeOfSteel_A400', 'Pastry', 'Z_Scratch']
# 	0.1s = Fit runtime
# 	29 features in original data used to generate 29 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.74 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 17297, Val Rows: 1922
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ... Training model for up to 599.89s of the 599.88s of remaining time.
# Fitting TabularPredictor for label: K_Scatch ...
# 	0.9423	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 599.68s of the 599.68s of remaining time.
# 	0.9398	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 599.47s of the 599.47s of remaining time.
# 	0.9892	 = Validation score   (roc_auc)
# 	2.03s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 597.36s of the 597.36s of remaining time.
# 	0.9886	 = Validation score   (roc_auc)
# 	1.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 595.87s of the 595.87s of remaining time.
# 	0.9882	 = Validation score   (roc_auc)
# 	10.38s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 585.35s of the 585.35s of remaining time.
# 	0.9881	 = Validation score   (roc_auc)
# 	9.74s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 575.48s of the 575.48s of remaining time.
# 	0.9881	 = Validation score   (roc_auc)
# 	6.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 569.41s of the 569.41s of remaining time.
# 	0.9871	 = Validation score   (roc_auc)
# 	2.39s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 566.81s of the 566.81s of remaining time.
# 	0.9877	 = Validation score   (roc_auc)
# 	3.58s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 563.05s of the 563.05s of remaining time.
# 	0.9855	 = Validation score   (roc_auc)
# 	16.37s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 546.62s of the 546.62s of remaining time.
# 	0.9885	 = Validation score   (roc_auc)
# 	1.96s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 544.64s of the 544.64s of remaining time.
# 	0.9883	 = Validation score   (roc_auc)
# 	26.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 517.71s of the 517.71s of remaining time.
# 	0.9867	 = Validation score   (roc_auc)
# 	3.8s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 513.75s of remaining time.
# 	Ensemble Weights: {'LightGBMXT': 0.458, 'LightGBM': 0.167, 'ExtraTreesEntr': 0.125, 'RandomForestGini': 0.083, 'NeuralNetTorch': 0.083, 'KNeighborsUnif': 0.042, 'XGBoost': 0.042}
# 	0.9895	 = Validation score   (roc_auc)
# 	0.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 86.51s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 4232.1 rows/s (1922 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20250627_135331/Predictor_K_Scatch")
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
# CPU Count:          2
# Memory Avail:       10.52 GB / 12.67 GB (83.0%)
# Disk Space Avail:   69.35 GB / 112.64 GB (61.6%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "/content/AutogluonModels/ag-20250627_135331/Predictor_Stains"
# Train Data Rows:    19219
# Train Data Columns: 30
# Label Column:       Stains
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10777.64 MB
# 	Train Data (Original)  Memory Usage: 4.40 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 17 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  5 | ['TypeOfSteel_A300', 'TypeOfSteel_A400', 'Pastry', 'Z_Scratch', 'K_Scatch']
# 	0.1s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.76 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 17297, Val Rows: 1922
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ... Training model for up to 599.85s of the 599.85s of remaining time.
# Fitting TabularPredictor for label: Stains ...
# 	0.8597	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 599.65s of the 599.65s of remaining time.
# 	0.8615	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 599.45s of the 599.45s of remaining time.
# 	0.9946	 = Validation score   (roc_auc)
# 	1.97s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 597.40s of the 597.40s of remaining time.
# 	0.9953	 = Validation score   (roc_auc)
# 	1.38s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 595.98s of the 595.98s of remaining time.
# 	0.9935	 = Validation score   (roc_auc)
# 	6.73s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 589.11s of the 589.11s of remaining time.
# 	0.9943	 = Validation score   (roc_auc)
# 	5.52s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 583.48s of the 583.48s of remaining time.
# 	0.9946	 = Validation score   (roc_auc)
# 	2.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 580.79s of the 580.79s of remaining time.
# 	0.9947	 = Validation score   (roc_auc)
# 	1.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 579.00s of the 579.00s of remaining time.
# 	0.9942	 = Validation score   (roc_auc)
# 	1.66s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 577.21s of the 577.21s of remaining time.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-6-1436900585.py in <cell line: 0>()
#       1 multi_predictor = MultilabelPredictor(labels=labels, problem_types=problem_types, eval_metrics=eval_metrics, consider_labels_correlation = True)
# ----> 2 multi_predictor.fit(train_data, time_limit=600)
#
# /tmp/ipython-input-2-1773515831.py in fit(self, train_data, tuning_data, **kwargs)
#      92                 tuning_data = tuning_data_og.drop(labels_to_drop, axis=1)
#      93             print(f"Fitting TabularPredictor for label: {label} ...")
# ---> 94             predictor.fit(train_data=train_data, tuning_data=tuning_data, **kwargs)
#      95             self.predictors[label] = predictor.path
#      96             if save_metrics:
#
# /usr/local/lib/python3.11/dist-packages/autogluon/core/utils/decorators.py in _call(*args, **kwargs)
#      29         def _call(*args, **kwargs):
#      30             gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31             return f(*gargs, **gkwargs)
#      32
#      33         return _call
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/predictor/predictor.py in fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, fit_strategy, memory_limit, callbacks, **kwargs)
#    1299         self._fit_strategy = fit_strategy
#    1300
# -> 1301         self._fit(ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1302
#    1303         return self
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/predictor/predictor.py in _fit(self, ag_fit_kwargs, ag_post_fit_kwargs)
#    1305     def _fit(self, ag_fit_kwargs: dict, ag_post_fit_kwargs: dict):
#    1306         self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# -> 1307         self._learner.fit(**ag_fit_kwargs)
#    1308         self._set_post_fit_vars()
#    1309         self._post_fit(**ag_post_fit_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/learner/abstract_learner.py in fit(self, X, X_val, **kwargs)
#     157             raise AssertionError("Learner is already fit.")
#     158         self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 159         return self._fit(X=X, X_val=X_val, **kwargs)
#     160
#     161     def _fit(
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/learner/default_learner.py in _fit(self, X, X_val, X_test, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, raise_on_model_failure, **trainer_fit_kwargs)
#     131
#     132         self.save()
# --> 133         trainer.fit(
#     134             X=X,
#     135             y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/auto_trainer.py in fit(self, X, y, hyperparameters, X_val, y_val, X_test, y_test, X_unlabeled, holdout_frac, num_stack_levels, core_kwargs, aux_kwargs, time_limit, infer_limit, infer_limit_batch_size, use_bag_holdout, groups, callbacks, **kwargs)
#     133         logger.log(20, log_str)
#     134
# --> 135         self._train_multi_and_ensemble(
#     136             X=X,
#     137             y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_multi_and_ensemble(self, X, y, X_val, y_val, X_test, y_test, hyperparameters, X_unlabeled, num_stack_levels, time_limit, groups, **kwargs)
#    3309             self._num_rows_test = len(X_test)
#    3310         self._num_cols_train = len(list(X.columns))
# -> 3311         model_names_fit = self.train_multi_levels(
#    3312             X,
#    3313             y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in train_multi_levels(self, X, y, hyperparameters, X_val, y_val, X_test, y_test, X_unlabeled, base_model_names, core_kwargs, aux_kwargs, level_start, level_end, time_limit, name_suffix, relative_stack, level_time_modifier, infer_limit, infer_limit_batch_size, callbacks)
#     504                 core_kwargs_level["time_limit"] = core_kwargs_level.get("time_limit", time_limit_core)
#     505                 aux_kwargs_level["time_limit"] = aux_kwargs_level.get("time_limit", time_limit_aux)
# --> 506             base_model_names, aux_models = self.stack_new_level(
#     507                 X=X,
#     508                 y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in stack_new_level(self, X, y, models, X_val, y_val, X_test, y_test, X_unlabeled, level, base_model_names, core_kwargs, aux_kwargs, name_suffix, infer_limit, infer_limit_batch_size, full_weighted_ensemble, additional_full_weighted_ensemble)
#     704             core_kwargs["name_suffix"] = core_kwargs.get("name_suffix", "") + name_suffix
#     705             aux_kwargs["name_suffix"] = aux_kwargs.get("name_suffix", "") + name_suffix
# --> 706         core_models = self.stack_new_level_core(
#     707             X=X,
#     708             y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in stack_new_level_core(self, X, y, models, X_val, y_val, X_test, y_test, X_unlabeled, level, base_model_names, fit_strategy, stack_name, ag_args, ag_args_fit, ag_args_ensemble, included_model_types, excluded_model_types, ensemble_type, name_suffix, get_models_func, refit_full, infer_limit, infer_limit_batch_size, **kwargs)
#     855
#     856         # FIXME: TODO: v0.1 X_unlabeled isn't cached so it won't be available during refit_full or fit_extra.
# --> 857         return self._train_multi(
#     858             X=X_init,
#     859             y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_multi(self, X, y, models, hyperparameter_tune_kwargs, feature_prune_kwargs, k_fold, n_repeats, n_repeat_start, time_limit, delay_bag_sets, **kwargs)
#    3241         if n_repeat_start == 0:
#    3242             time_start = time.time()
# -> 3243             model_names_trained = self._train_multi_initial(
#    3244                 X=X,
#    3245                 y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_multi_initial(self, X, y, models, k_fold, n_repeats, hyperparameter_tune_kwargs, time_limit, feature_prune_kwargs, **kwargs)
#    2826         if not bagged:
#    2827             time_ratio = hpo_time_ratio if hpo_enabled else 1
# -> 2828             models = self._train_multi_fold(
#    2829                 models=models,
#    2830                 hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_multi_fold(self, X, y, models, time_limit, time_split, time_ratio, hyperparameter_tune_kwargs, fit_strategy, **kwargs)
#    2993                     return models_valid
#    2994
# -> 2995                 models_valid += _detached_train_multi_fold(
#    2996                     _self=self,
#    2997                     model=model,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _detached_train_multi_fold(_self, model, X, y, time_split, time_start, time_limit, time_limit_model_split, hyperparameter_tune_kwargs, is_ray_worker, kwargs)
#    4584             time_left=time_limit-(time_start_model-time_start)
#    4585
# -> 4586     model_name_trained_lst = _self._train_single_full(
#    4587         X,
#    4588         y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_single_full(self, X, y, model, X_unlabeled, X_val, y_val, X_test, y_test, X_pseudo, y_pseudo, hyperparameter_tune_kwargs, stack_name, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, level, time_limit, fit_kwargs, compute_score, total_resources, errors, errors_ignore, errors_raise, is_ray_worker, **kwargs)
#    2609                 )
#    2610                 model_fit_kwargs.update(bagged_model_fit_kwargs)
# -> 2611             model_names_trained = self._train_and_save(
#    2612                 X=X,
#    2613                 y=y,
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_and_save(self, X, y, model, X_val, y_val, X_test, y_test, X_pseudo, y_pseudo, time_limit, stack_name, level, compute_score, total_resources, errors, errors_ignore, errors_raise, is_ray_worker, **model_fit_kwargs)
#    2167         exception = None
#    2168         try:
# -> 2169             model = self._train_single(**model_fit_kwargs)
#    2170
#    2171             fit_end_time = time.time()
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/trainer/abstract_trainer.py in _train_single(self, X, y, model, X_val, y_val, X_test, y_test, total_resources, **model_fit_kwargs)
#    2053         Returns trained model object.
#    2054         """
# -> 2055         model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#    2056         return model
#    2057
#
# /usr/local/lib/python3.11/dist-packages/autogluon/core/models/abstract/abstract_model.py in fit(self, **kwargs)
#    1049                 logger.warning(f'\tWarning: Model has no time left to train, skipping model... (Time Left = {kwargs["time_limit"]:.1f}s)')
#    1050                 raise TimeLimitExceeded
# -> 1051         out = self._fit(**kwargs)
#    1052         if out is None:
#    1053             out = self
#
# /usr/local/lib/python3.11/dist-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py in _fit(self, X, y, X_val, y_val, time_limit, num_cpus, num_gpus, sample_weight, **kwargs)
#     375                         raise TimeLimitExceeded
#     376
# --> 377                     self.model.fit_one_cycle(epochs, params["lr"], cbs=callbacks)
#     378
#     379                     # Load the best one and export it
#
# /usr/local/lib/python3.11/dist-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt, start_epoch)
#     119     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     120               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 121     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#     122
#     123 # %% ../../nbs/14_callback.schedule.ipynb 50
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     270             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     271             self.n_epoch = n_epoch
# --> 272             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     273
#     274     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     205
#     206     def _with_events(self, f, event_type, ex, final=noop):
# --> 207         try: self(f'before_{event_type}');  f()
#     208         except ex: self(f'after_cancel_{event_type}')
#     209         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _do_fit(self)
#     259         for epoch in range(self.n_epoch):
#     260             self.epoch=epoch
# --> 261             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     262
#     263     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False, start_epoch=0):
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     205
#     206     def _with_events(self, f, event_type, ex, final=noop):
# --> 207         try: self(f'before_{event_type}');  f()
#     208         except ex: self(f'after_cancel_{event_type}')
#     209         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _do_epoch(self)
#     253
#     254     def _do_epoch(self):
# --> 255         self._do_epoch_train()
#     256         self._do_epoch_validate()
#     257
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _do_epoch_train(self)
#     245     def _do_epoch_train(self):
#     246         self.dl = self.dls.train
# --> 247         self._with_events(self.all_batches, 'train', CancelTrainException)
#     248
#     249     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     205
#     206     def _with_events(self, f, event_type, ex, final=noop):
# --> 207         try: self(f'before_{event_type}');  f()
#     208         except ex: self(f'after_cancel_{event_type}')
#     209         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in all_batches(self)
#     211     def all_batches(self):
#     212         self.n_iter = len(self.dl)
# --> 213         for o in enumerate(self.dl): self.one_batch(*o)
#     214
#     215     def _backward(self): self.loss_grad.backward()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in one_batch(self, i, b)
#     241         b = self._set_device(b)
#     242         self._split(b)
# --> 243         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     244
#     245     def _do_epoch_train(self):
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     205
#     206     def _with_events(self, f, event_type, ex, final=noop):
# --> 207         try: self(f'before_{event_type}');  f()
#     208         except ex: self(f'after_cancel_{event_type}')
#     209         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _do_one_batch(self)
#     229         self('after_loss')
#     230         if not self.training or not len(self.yb): return
# --> 231         self._do_grad_opt()
#     232
#     233     def _set_device(self, b):
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _do_grad_opt(self)
#     218     def _do_grad_opt(self):
#     219         self._with_events(self._backward, 'backward', CancelBackwardException)
# --> 220         self._with_events(self._step, 'step', CancelStepException)
#     221         self.opt.zero_grad()
#     222
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     205
#     206     def _with_events(self, f, event_type, ex, final=noop):
# --> 207         try: self(f'before_{event_type}');  f()
#     208         except ex: self(f'after_cancel_{event_type}')
#     209         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py in _step(self)
#     214
#     215     def _backward(self): self.loss_grad.backward()
# --> 216     def _step(self): self.opt.step()
#     217
#     218     def _do_grad_opt(self):
#
# /usr/local/lib/python3.11/dist-packages/fastai/optimizer.py in step(self, closure)
#     111         if closure is not None: raise NotImplementedError("fastai optimizers currently do not support closure")
#     112         for p,pg,state,hyper in self.all_params(with_grad=True):
# --> 113             for cb in self.cbs: state = _update(state, cb(p, **{**state, **hyper}))
#     114             self.state[p] = state
#     115
#
# KeyboardInterrupt:
